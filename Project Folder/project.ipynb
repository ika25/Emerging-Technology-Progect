# %% [markdown]
# # Emerging Technologies Project 2020/21
#
# ###### Irakli Lomidze G00275525

# %% [markdown]
# ********

# %% [markdown]
# ## Task
# In this project you must create a web service that uses machine learning to make predictions based on the data set powerproduction. The goal is to produce a model that accurately predicts wind turbine power output from wind speed values, as in the data set.
#
# ### About wind energy
# #### How wind energy is created
# The sun heats the earth unevenly and this creates thermal air currents. In order to achieve equal temperatures around the earth, these air pockets move about as global wind. The energy that travels in the wind can be captured and converted to provide electricity.
#
# #### Clean and sustainable energy
# Wind energy provides a clean, sustainable solution to our energy problems. It can be used as an alternative to fossil fuels in generating electricity, without the direct emission of greenhouse gases. And there will always be wind; it is inexhaustible and renewable.
#
# * Reference: https://www.seai.ie/technologies/wind-energy/?gclid=CjwKCAiAouD_BRBIEiwALhJH6GEhcKIAp1E83Zh9RgSqvjgMl9JsPHT3pKbvzm_E0U6s8tVQv0IuxhoCeFAQAvD_BwE

# %% [markdown]
# ******

# %% [markdown]
# ## Power Production Data Set

# %% [markdown]
# ### Imports

# %%
# data frames
import pandas as pd
# plotting
import matplotlib.pyplot as plt
# neural networks
import tensorflow.keras as krs
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.models import Model
# numerical arrays
import numpy as np
# make numpy values easier to read
np.set_printoptions(precision=3, suppress=True)

# %%
# plot style
plt.style.use("ggplot")
# plot size
plt.rcParams['figure.figsize'] = [14, 8]

# %%
# load dataset from csv file
powerproduction = pd.read_csv("powerproduction.txt")

# %% [markdown]
# ### Sample data set

# %%
# referance: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
# turn dataset into dataframe
DataSet = pd.DataFrame(powerproduction)

# output dataFrame sample
DataSet.sample()
# Out:
#       speed   power
# 268  13.564  63.383

# %% [markdown]
# ## Data Set Graph

# %%
# referance : https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html, https://datatofish.com/plot-dataframe-pandas/
# plot dataset
plt.title('Power Production Data Set')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.plot(DataSet['power'], 'o', color="#1b55b3", markersize=3, label='Power')
plt.ylabel('Wind Turbine Power')
plt.xlabel('Wind Speed')
plt.legend()

# %% [markdown]
# *******

# %% [markdown]
# ## Training Model
# Building a Sequential Model that has a Sigmoid and Linear Layer.

# %%
# train model
model = krs.models.Sequential()
model.add(Dense(50, input_shape=(1,), activation='sigmoid', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform"))
model.add(Dense(1, activation='linear', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform"))
# compile model
model.compile(krs.optimizers.Adam(lr=0.001), loss='mean_squared_error', metrics=['accuracy'])

# %%
# reference: https://machinelearningmastery.com/evaluate-performance-deep-learning-models-keras/, https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
# fit the data
m1history = model.fit(DataSet['speed'], DataSet['power'], epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 980us/step - loss: 3814.9294 - accuracy: 0.0000e+00
# Epoch 2/500
# 50/50 [==============================] - 0s 1ms/step - loss: 3655.9177 - accuracy: 0.0000e+00
# Epoch 3/500
# 50/50 [==============================] - 0s 1ms/step - loss: 3466.0405 - accuracy: 0.0000e+00
# Epoch 4/500
# 50/50 [==============================] - 0s 1ms/step - loss: 3210.3159 - accuracy: 0.0000e+00
# Epoch 5/500
# 50/50 [==============================] - 0s 1ms/step - loss: 2970.3447 - accuracy: 0.0000e+00
# Epoch 6/500
# 50/50 [==============================] - 0s 1ms/step - loss: 2799.6082 - accuracy: 0.0000e+00
# Epoch 7/500
# 50/50 [==============================] - 0s 860us/step - loss: 2653.5898 - accuracy: 0.0000e+00
# Epoch 8/500
# 50/50 [==============================] - 0s 920us/step - loss: 2526.6880 - accuracy: 0.0000e+00
# Epoch 9/500
# 50/50 [==============================] - 0s 940us/step - loss: 2415.6807 - accuracy: 0.0000e+00
# ...

# %% [markdown]
# ### Training model summery

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 50)                100
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Data prrediction

# %%
# reference: https://machinelearningmastery.com/make-predictions-scikit-learn/, https://towardsdatascience.com/step-by-step-guide-building-a-prediction-model-in-python-ac441e8b9e8b
# turn prediction into data.
dataPredict = pd.DataFrame(model.predict(DataSet['speed']), columns=['speed'])

# output prediction
dataPredict.head()
# Out:
#       speed
# 0  1.854773
# 1  1.905898
# 2  1.916240
# 3  1.947498
# 4  1.968529

# %%
# Plot our predictions of the SPEED values we trained on
plt.title('Power Production Wind Speed')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.xlabel('Wind Speed')
plt.legend()

# %%
# save prediction result to a .h5 file
model.save("newmodel.h5")

# %% [markdown]
# ********

# %% [markdown]
# ## Train model 2
# Building a Sequential Model that has Linear Layer.

# %%
# creeating a sequential nural network model
model2 = krs.models.Sequential()
model2.add(Dense(50, input_shape=(1,), activation="linear", kernel_initializer='ones', bias_initializer='zeros'))
model2.add(Dense(1, input_shape=(1,), activation="linear", kernel_initializer='ones', bias_initializer='zeros'))
# compile model
model2.compile(krs.optimizers.Adam(lr=0.001), loss='mean_squared_error', metrics=['accuracy'])

# %%
# fit the data
m2history = model2.fit(DataSet['speed'], DataSet['power'], epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 1ms/step - loss: 398407.2500 - accuracy: 0.0020
# Epoch 2/500
# 50/50 [==============================] - 0s 1ms/step - loss: 320706.8125 - accuracy: 0.0020
# Epoch 3/500
# 50/50 [==============================] - 0s 1ms/step - loss: 258912.5938 - accuracy: 0.0060
# Epoch 4/500
# 50/50 [==============================] - 0s 1ms/step - loss: 210182.6875 - accuracy: 0.0060
# Epoch 5/500
# 50/50 [==============================] - 0s 961us/step - loss: 171689.5000 - accuracy: 0.0100
# Epoch 6/500
# 50/50 [==============================] - 0s 980us/step - loss: 140531.0781 - accuracy: 0.0100
# Epoch 7/500
# 50/50 [==============================] - 0s 1000us/step - loss: 115930.8594 - accuracy: 0.0100
# Epoch 8/500
# 50/50 [==============================] - 0s 999us/step - loss: 96007.7109 - accuracy: 0.0100
# Epoch 9/500
# 50/50 [==============================] - 0s 1ms/step - loss: 79747.8984 - accuracy: 0.0100
# Epoch 10/500
# ...

# %% [markdown]
# ### Training model summery

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Data prrediction

# %%
# turn prediction into data.
dataPredict = pd.DataFrame(model.predict(DataSet['speed']), columns=['speed'])

# output prediction
dataPredict.head()
# Out:
#       speed
# 0  1.854773
# 1  1.905898
# 2  1.916240
# 3  1.947498
# 4  1.968529

# %%
# Plot our predictions of the SPEED values we trained on
plt.title('Power Production Wind Speed')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.xlabel('Wind Speed')
plt.legend()

# %%
# save prediction result to a .h5 file
model.save("newmodel2.h5")

# %% [markdown]
# ******

# %% [markdown]
# # Train model 3
# set the data into Numpy arrays

# %%
# referance: https://keras.io/getting_started/intro_to_keras_for_engineers/
# dataset as numpy arrays
x = DataSet.iloc[:,0].values
y = DataSet.iloc[:,1].values

X = np.array
Y = np.array

# %%
# reference: https://keras.io/api/layers/activations/, https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6
krsInput = krs.Input(shape=(1,)) 
layer1 = Dense(10, activation='elu', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(krsInput)
layer2 = Dense(50, activation='tanh', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(layer1)
layer3 = Dense(50, activation='tanh', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(layer2)
layer4 = Dense(50, activation='tanh', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(layer3)
layer5 = Dense(50, activation='tanh', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(layer4)
layer6 = Dense(50, activation='tanh', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform")(layer5)
output = Dense(1)(layer6)

# %%
# compile model
model3 = Model(inputs=krsInput, outputs=[output])
model3.compile(optimizer='adam', loss=['mean_squared_error'], metrics=['accuracy'])

# %%
m3history = model3.fit(x, y, epochs=5000, batch_size=500)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 4050.2578 - accuracy: 0.0980
# Epoch 2/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 4012.9099 - accuracy: 0.0980
# Epoch 3/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 3975.9756 - accuracy: 0.0700
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 3939.6062 - accuracy: 0.0460
# Epoch 5/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 3904.1990 - accuracy: 0.0260
# Epoch 6/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 3870.4260 - accuracy: 0.0140
# Epoch 7/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 3838.8206 - accuracy: 0.0100
# Epoch 8/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 3809.4861 - accuracy: 0.0080
# Epoch 9/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 3782.1431 - accuracy: 0.0020
# Epoch 10/5000
# ...

# %% [markdown]
# ### Trainind model summery

# %%
model3.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                550
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                2550
# ...

# %% [markdown]
# ### Data prrediction

# %%
# turn prediction into data.
dataPredict = pd.DataFrame(model.predict(DataSet['speed']), columns=['speed'])

# output prediction
dataPredict.head()
# Out:
#       speed
# 0  1.854773
# 1  1.905898
# 2  1.916240
# 3  1.947498
# 4  1.968529

# %%
# save prediction result to a .h5 file
model.save("newmodel3.h5")

# %% [markdown]
# # Comparing Models

# %% [markdown]
# ## Model 1

# %%
# reference: https://medium.com/intuitive-deep-learning/build-your-first-neural-network-to-predict-house-prices-with-keras-eb5db60232c
# plot accuracy of model 1
plt.plot(m1history.history['accuracy'])
plt.title('Comaparing Model Accuracy')

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %%
# turn model 1 accuracy into data frame
model1Acc = pd.DataFrame(m1history.history['accuracy'], columns=['Model Accuracy ='])

# output mean of model accuracy 
print("Over 500 Epochs the Model has an accuracy of:")
model1Acc.mean()
# Out:
# Over 500 Epochs the Model has an accuracy of:
# Model Accuracy =    0.018168
# dtype: float64

# %%
#reference: https://medium.com/intuitive-deep-learning/build-your-first-neural-network-to-predict-house-prices-with-keras-eb5db60232c

# %%
# plot the losses of model 1
plt.plot(m1history.history['loss'])
plt.title('Model 1 Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %% [markdown]
# ### mean loss and minimum loss

# %%
# turn model losses into data frame
model1Loss = pd.DataFrame(m1history.history['loss'], columns=['Loss ='])

# output mean loss
model1Loss.mean()
# Out:
# Loss =    415.699715
# dtype: float64

# %%
# output minium loss from model
model1Loss.min()
# Out:
# Loss =    250.88269
# dtype: float64

# %% [markdown]
# ### prediction as compared to original

# %%
# plot model 1
plt.title('Original Data and Predicted Data from Model 1')
plt.plot(DataSet['speed'], DataSet['power'], 'o', color="blue", markersize=2, label='Original Data')
plt.plot(DataSet['speed'], model.predict(DataSet['speed']), '-', color="orange", markersize=2, label='Prediction')
plt.legend();

# %%
#reference: https://medium.com/intuitive-deep-learning/build-your-first-neural-network-to-predict-house-prices-with-keras-eb5db60232c

# %% [markdown]
# ## Model 2

# %%
# plot accuracy of model 2
plt.plot(m2history.history['accuracy'])
plt.title('Comaparing Model Accuracy')

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %%
# turn model 2 accuracy into data frame
model2Acc = pd.DataFrame(m2history.history['accuracy'], columns=['Model Accuracy ='])

# output mean of model accuracy 
print("Over 500 Epochs the Model has an accuracy of:")
model2Acc.mean()
# Out:
# Over 500 Epochs the Model has an accuracy of:
# Model Accuracy =    0.03258
# dtype: float64

# %% [markdown]
# ### loses

# %%
# plot the losses of model 2
plt.plot(m2history.history['loss'])
plt.title('Model 2 Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %%
# turn model losses into data frame
model2Loss = pd.DataFrame(m2history.history['loss'], columns=['Loss ='])

# output mean loss
model2Loss.mean()
# Out:
# Loss =    4926.667255
# dtype: float64

# %%
# Minimum loss
model2Loss.min()
# Out:
# Loss =    468.697449
# dtype: float64

# %% [markdown]
# ### prediction as compared to original

# %%
# plot model 2
plt.title('Original Data and Predicted Data from Model 2')
plt.plot(DataSet['speed'], DataSet['power'], 'o', color="blue", markersize=2, label='Original Data')
plt.plot(DataSet['speed'], model2.predict(DataSet['speed']), '-', color="orange", markersize=2, label='Prediction')
plt.legend();

# %%
#reference: https://medium.com/intuitive-deep-learning/build-your-first-neural-network-to-predict-house-prices-with-keras-eb5db60232c

# %% [markdown]
# ## Model 3

# %%
# plot accuracy of model 3
plt.plot(m3history.history['accuracy'])
plt.title('Comaparing Model Accuracy')

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %%
# turn model 3 accuracy into data frame
model3Acc = pd.DataFrame(m3history.history['accuracy'], columns=['Model Accuracy ='])

# output mean of model accuracy 
print("Over 500 Epochs the Model has an accuracy of:")
model3Acc.mean()
# Out:
# Over 500 Epochs the Model has an accuracy of:
# Model Accuracy =    0.003534
# dtype: float64

# %% [markdown]
# ## Loses

# %%
# plot the losses of model 3
plt.plot(m3history.history['loss'])
plt.title('Model 3 Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')

# %%
# turn model losses into data frame
model3Loss = pd.DataFrame(m3history.history['loss'], columns=['Loss ='])

# output mean loss
model3Loss.mean()
# Out:
# Loss =    630.415349
# dtype: float64

# %%
#minimum losses
model3Loss.min()
# Out:
# Loss =    246.733154
# dtype: float64

# %% [markdown]
# ## predicted compared to original

# %%
# plot model 3
plt.title('Original Data and Predicted Data from Model 3')
plt.plot(DataSet['speed'], DataSet['power'], 'o', color="blue", markersize=2, label='Original Data')
plt.plot(DataSet['speed'], model3.predict(DataSet['speed']), '-', color="orange", markersize=2, label='Prediction')
plt.legend();

# %%
#reference: https://medium.com/intuitive-deep-learning/build-your-first-neural-network-to-predict-house-prices-with-keras-eb5db60232c

# %% [markdown]
# *******

# %% [markdown]
# # Conclusion
#
# Model  2 :
# This has good accuracy but upon visualisation and loss calculation it did not turn out to be a good model
#
# Model 1 :
# This has a lower loss but was lacking in accuracy.
#
# Model 3:
# Model 3 had the least loss out of the thre models and also the predictions are looking good.
#
# I have tested with the integrated webservices and looks good to propse as the model for my assignment.

# %% [markdown]
# **************

# %% [markdown]
# # References
#
# * https://stackabuse.com/deep-learning-in-keras-building-a-deep-learning-model/
# * https://keras.io/guides/sequential_model/
# * https://towardsdatascience.com/building-our-first-neural-network-in-keras-bdc8abbc17f5
# * https://www.datacamp.com/community/tutorials/deep-learning-python
# * https://machinelearningmastery.com/evaluate-performance-deep-learning-models-keras/
# * https://towardsdatascience.com/step-by-step-guide-building-a-prediction-model-in-python-ac441e8b9e8b
# * https://machinelearningmastery.com/make-predictions-scikit-learn/
# * https://www.dataquest.io/blog/numpy-tutorial-python/
# * https://machinelearningmastery.com/how-to-save-a-numpy-array-to-file-for-machine-learning/
# * https://keras.io/getting_started/intro_to_keras_for_engineers/
# * https://keras.io/examples/vision/mnist_convnet/
# * https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam
# * https://www.tensorflow.org/guide/keras/train_and_evaluate
# * https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# * https://machinelearningmastery.com/save-load-keras-deep-learning-models/
#
# ### Flask
#
# * https://www.freecodecamp.org/news/how-to-build-a-web-application-using-flask-and-deploy-it-to-the-cloud-3551c985e492/
# * https://towardsdatascience.com/building-a-web-application-to-deploy-machine-learning-models-e224269c1331
# * https://flask.palletsprojects.com/en/1.1.x/
# * https://programminghistorian.org/en/lessons/creating-apis-with-python-and-flask
# * https://opensource.com/article/18/4/flask
#
# ### LearnOnline
#
# * https://web.microsoftstream.com/video/bf7aaf56-d65f-47fb-aec9-e0c2af49534a?referrer=https:%2F%2Flearnonline.gmit.ie%2F
# * https://web.microsoftstream.com/video/8ceee222-ebdf-4234-b05b-9090155f1747
# * https://web.microsoftstream.com/video/ed1d0b97-441b-4e60-9ecf-b2e775d6bb7c

# %% [markdown]
# *************

# %% [markdown]
# # Emerging Technologies Project 2020/21

# %% [markdown]
# ********

# %% [markdown]
# ## Task
# ### In this project you must create a web service that uses machine learning to make predictions based on the data set powerproduction. The goal is to produce a model that accurately predicts wind turbine power output from wind speed values, as in the data set.

# %% [markdown]
# ******

# %% [markdown]
# ## Power Production Data Set

# %%
# data frames
import pandas as pd
# plotting
import matplotlib.pyplot as plt
# neural networks
import tensorflow.keras as krs
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.models import Model
# numerical arrays
import numpy as np
# make numpy values easier to read
np.set_printoptions(precision=3, suppress=True)

# %%
# plot style
plt.style.use("ggplot")
# plot size
plt.rcParams['figure.figsize'] = [14, 8]

# %%
# load dataset from csv file
powerproduction = pd.read_csv("powerproduction.txt")

# %% [markdown]
# ### Sample data set

# %%
# referance: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
# turn dataset into dataframe
DataSet = pd.DataFrame(powerproduction)

# output dataFrame sample
DataSet.sample()
# Out:
#       speed  power
# 437  22.072  99.46

# %% [markdown]
# ## Data Set Graph

# %%
# referance : https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html, https://datatofish.com/plot-dataframe-pandas/
# plot dataset
plt.title('Power Production Data Set')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.plot(DataSet['power'], 'o', color="#1b55b3", markersize=3, label='Power')
plt.ylabel('Wind Turbine Power')
plt.xlabel('Wind Speed')
plt.legend()

# %% [markdown]
# *******

# %% [markdown]
# ## Training Model
# Building a Sequential Model that has a Sigmoid and Linear Layer.

# %%
# train model
model = krs.models.Sequential()
model.add(Dense(50, input_shape=(1,), activation='sigmoid', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform"))
model.add(Dense(1, activation='linear', kernel_initializer="glorot_uniform", bias_initializer="glorot_uniform"))
# compile model
model.compile(krs.optimizers.Adam(lr=0.001), loss='mean_squared_error', metrics=['accuracy'])

# %%
# reference: https://machinelearningmastery.com/evaluate-performance-deep-learning-models-keras/, https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
# fit the data
model.fit(DataSet['speed'], DataSet['power'], epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 940us/step - loss: 253.5277 - accuracy: 0.0000e+00
# Epoch 2/500
# 50/50 [==============================] - 0s 901us/step - loss: 253.2984 - accuracy: 0.0000e+00
# Epoch 3/500
# 50/50 [==============================] - 0s 840us/step - loss: 253.2514 - accuracy: 0.0000e+00
# Epoch 4/500
# 50/50 [==============================] - 0s 960us/step - loss: 253.2179 - accuracy: 0.0000e+00
# Epoch 5/500
# 50/50 [==============================] - 0s 940us/step - loss: 253.1446 - accuracy: 0.0000e+00
# Epoch 6/500
# 50/50 [==============================] - 0s 1ms/step - loss: 253.1227 - accuracy: 0.0000e+00
# Epoch 7/500
# 50/50 [==============================] - 0s 873us/step - loss: 253.2522 - accuracy: 0.0000e+00
# Epoch 8/500
# 50/50 [==============================] - 0s 875us/step - loss: 253.6768 - accuracy: 0.0000e+00
# Epoch 9/500
# 50/50 [==============================] - 0s 945us/step - loss: 253.3215 - accuracy: 0.0000e+00
# ...

# %% [markdown]
# ### Training model summery

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 50)                100
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Data prrediction

# %%
# reference: https://machinelearningmastery.com/make-predictions-scikit-learn/, https://towardsdatascience.com/step-by-step-guide-building-a-prediction-model-in-python-ac441e8b9e8b
# turn prediction into data.
dataPredict = pd.DataFrame(model.predict(DataSet['speed']), columns=['speed'])

# output prediction
dataPredict.head()
# Out:
#       speed
# 0  2.674411
# 1  2.694728
# 2  2.698804
# 3  2.711039
# 4  2.719193

# %%
# Plot our predictions of the SPEED values we trained on
plt.title('Power Production Wind Speed')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.xlabel('Wind Speed')
plt.legend()

# %%
# save prediction result to a .h5 file
model.save("model.h5")

# %% [markdown]
# ********

# %% [markdown]
# ## Train model 2
# Building a Sequential Model that has Linear Layer.

# %%
# creeating a sequential nural network model
model = krs.models.Sequential()
model.add(Dense(50, input_shape=(1,), activation="linear", kernel_initializer='ones', bias_initializer='zeros'))
model.add(Dense(1, input_shape=(1,), activation="linear", kernel_initializer='ones', bias_initializer='zeros'))
# compile model
model.compile(krs.optimizers.Adam(lr=0.001), loss='mean_squared_error', metrics=['accuracy'])

# %%
# fit the data
model.fit(DataSet['speed'], DataSet['power'], epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 940us/step - loss: 400838.4062 - accuracy: 0.0020
# Epoch 2/500
# 50/50 [==============================] - 0s 920us/step - loss: 322326.6562 - accuracy: 0.0020
# Epoch 3/500
# 50/50 [==============================] - 0s 939us/step - loss: 260880.8125 - accuracy: 0.0040
# Epoch 4/500
# 50/50 [==============================] - 0s 960us/step - loss: 211404.7969 - accuracy: 0.0060
# Epoch 5/500
# 50/50 [==============================] - 0s 960us/step - loss: 172704.1875 - accuracy: 0.0080
# Epoch 6/500
# 50/50 [==============================] - 0s 980us/step - loss: 141539.7969 - accuracy: 0.0100
# Epoch 7/500
# 50/50 [==============================] - 0s 940us/step - loss: 116544.0000 - accuracy: 0.0100
# Epoch 8/500
# 50/50 [==============================] - 0s 960us/step - loss: 96553.6250 - accuracy: 0.0100
# Epoch 9/500
# 50/50 [==============================] - 0s 940us/step - loss: 80205.3125 - accuracy: 0.0100
# ...

# %% [markdown]
# ### Training model summery

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Data prrediction

# %%
# turn prediction into data.
dataPredict = pd.DataFrame(model.predict(DataSet['speed']), columns=['speed'])

# output prediction
dataPredict.head()
# Out:
#        speed
# 0 -13.863234
# 1 -13.248065
# 2 -13.125031
# 3 -12.755929
# 4 -12.509863

# %%
# Plot our predictions of the SPEED values we trained on
plt.title('Power Production Wind Speed')
plt.plot(DataSet, 'o', markersize=2)
plt.plot(DataSet['speed'], 'o', color="#fc7405", markersize=3, label='Wind Speed')
plt.xlabel('Wind Speed')
plt.legend()

# %%
# save prediction result to a .h5 file
model.save("model.h5")
